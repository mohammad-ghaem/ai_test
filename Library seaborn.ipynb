# %%
# %matplotlib inline
import pandas as pd
import seaborn as sb

data = pd.read_csv ("cars.csv")

data.head() # نمایش اطلاعات به صورت عادی
Geard_data = data["# Gears"].value_counts()
Geard_data.plot(kind ='bar')

#نمایش اطلاعات به صورت گرافیکی

import seaborn as sb
sb.set()

# %%
data.head()
# Out:
#               Mfr Name     Carline  Eng Displ  Cylinders Transmission  \
# 0         aston martin  Vantage V8        4.0          8     Auto(S8)
# 1  Volkswagen Group of      Chiron        8.0         16  Auto(AM-S7)
# 2       General Motors    CORVETTE        6.2          8     Auto(S8)
# 3       General Motors    CORVETTE        6.2          8     Auto(S8)
# 4       General Motors    CORVETTE        6.2          8     Auto(S8)
#
#    CityMPG  HwyMPG  CombMPG  # Gears
# 0       18      25       21        8
# 1        9      14       11        7
# 2       12      20       15        8
# 3       15      25       18        8
# 4       14      23       17        8

# %%
df2 = data[['Cylinders' , 'CityMPG' ,'HwyMPG' ,'CombMPG']]
df2.head()
# Out:
#    Cylinders  CityMPG  HwyMPG  CombMPG
# 0          8       18      25       21
# 1         16        9      14       11
# 2          8       12      20       15
# 3          8       15      25       18
# 4          8       14      23       17

# %%
sb.pairplot(df2 , hue ='Cylinders' ,height = 2.5 )
# Out:
# /Users/ghaem/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ghaem/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /Users/ghaem/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sb.scatterplot(x='Mfr Name',y='Carline',data=data)
# Out:
# <AxesSubplot:xlabel='Mfr Name', ylabel='Carline'>

# %%
sb.jointplot(x='Mfr Name',y='Carline',data=data)
